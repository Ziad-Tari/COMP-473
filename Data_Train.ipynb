# %%
# %run training.py
# Out:
# RNG Seed:  999
# Loading CelebA dataset (Download size: 1.4GB)
# Files already downloaded and verified
# CelebA loaded (162770 images)
# Dataloader created: 1271 batches per epoch
# Batch size: 128
# Image size: 64 by 64
# Total batches: 1271
# [0/5][0/1271]	Loss_D: 1.6230	Loss_G: 5.8066	D(x): 0.5981	D(G(z)): 0.5731 / 0.0046
# [0/5][50/1271]	Loss_D: 1.2349	Loss_G: 26.7655	D(x): 0.9851	D(G(z)): 0.6179 / 0.0000
# [0/5][100/1271]	Loss_D: 0.2796	Loss_G: 5.9674	D(x): 0.9478	D(G(z)): 0.1457 / 0.0068
# [0/5][150/1271]	Loss_D: 0.5336	Loss_G: 3.7981	D(x): 0.7538	D(G(z)): 0.1220 / 0.0370
# [0/5][200/1271]	Loss_D: 0.4191	Loss_G: 4.3771	D(x): 0.7981	D(G(z)): 0.1165 / 0.0203
# [0/5][250/1271]	Loss_D: 0.7117	Loss_G: 6.3957	D(x): 0.8557	D(G(z)): 0.3239 / 0.0041
# [0/5][300/1271]	Loss_D: 0.4109	Loss_G: 4.7561	D(x): 0.8288	D(G(z)): 0.1494 / 0.0169
# [0/5][350/1271]	Loss_D: 0.6327	Loss_G: 5.1391	D(x): 0.9392	D(G(z)): 0.3793 / 0.0143
# ...
